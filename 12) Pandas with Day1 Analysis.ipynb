# %% [raw]
# Cassandra - Not only SQL (NOSQL)
# SQL : structured data( table, schema need, difficult to edit later)
# DB designed to designed fast search(indexing)
# cassandra - designed by facebook
# 1) scalability, 2) high availability (reason)
# 3) decentralize
# 4) durable
#
# what is scalability? 100gb then tomorrow 500gb growing more and more everymonth
# we need kind of system to configure as we progress in space (horizontally scalable with hardware and software)
# today(100gb) >> next year need (500gb) >> following year 1600gb.. still possible. In case of cassandra, existing h/w and s/w is tied with new h/w and s/w - gfs file system and hadoop system
#
# ex: old laptop + New laptop + latest laptop.... (share the computational power and RAM)
# All apps are using the cassandra system (facebook, uber, spotify, github..)
#
# SQL (vertical scalable system, scrap the existing h/w and s/w and do new system)
# ex: old laptop (not enough computational power) > replaced with new laptop (with good configuration)
#
# What is high availability?
# For example:
# test.txt file, write inside in a local system and this system is going to crash. when it does all the data is erased.
#
# whatever happen the system must be available for use, cloud system is nothing but multiple computer is interconnected.
# if we design a system such a way multiple datacenter in the different location is interconnected but you have registered/stored the data in nearby datacenter. in any case the nearby datacenter is down, what if the data you had in the datacenter is replicated the same data in other multiple location, ny having this kind of configuration the user/data stored person will not have any problem in accessing the data in datacenter/cloud which automatically link the access to other location when your intended datacenter down.
# this kind of system design is hogh availability
#
# ex: your datacenter(SG) <<--->> mumbai datacenter<<--->>virginia datacenter
#             ^
#             |
#             > User data(inueron.ai)
#
#        SG data center down, then i get the data from mumbai or virginia
#
# High availability is achieved by fault tolerant
# decentralized - blockchain, ft3.0
# replication factor is 3, 2, 4.. Location system / cluster
#
# 3. decentralized system: no single point of failure system / no network bottleneck system
# data is stored in multiple datacenters.
#
# 4) durable system: even the complete datacenter is going down and we are not worried about it. it still gets the data available from other datacenter
# elastic kind of property, both increases linearity on both vertical and horizontally, latency is decreased and read/write speed increased.
#
# commodity vs dedicated hardware
# commodity is cheaper, common system.

# %% [raw]
# google:
# datastax.com
# with gmail login
#
# database created:
# database: mohana
# keyspace: ineurontest

# %%
pip install cassandra-driver
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CE08-50A1
#
#  Directory of C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron
#
# 23/09/2022  11:35 AM    <DIR>          .
# 23/09/2022  11:35 AM    <DIR>          ..
# 22/09/2022  09:30 PM    <DIR>          .ipynb_checkpoints
# 21/08/2022  04:27 PM    <DIR>          __pycache__
# 10/08/2022  09:56 PM            69,297 1) Python basic_String_list_Indexing.ipynb
# 16/09/2022  07:25 AM            71,909 10) MongoDB.ipynb
# 17/09/2022  05:49 PM            19,322 10.1) Mongodb exercise.ipynb
# 21/09/2022  08:51 PM            74,018 11) SQL Lite, Map, Reduce, filter, zip.ipynb
# 23/09/2022  11:35 AM             5,172 12) Pandas.ipynb
# 10/08/2022  10:02 PM            50,566 2) Tuple, Set Dict.ipynb
# 10/08/2022  10:43 PM           226,340 3) 19Dec_Python Prog Discussion.ipynb
# 10/08/2022  10:58 PM            28,649 4) Function_23Dec21.ipynb
# 10/08/2022  11:34 PM            53,772 5) Function_Part2_8Jan22.ipynb
# ...

# %%
pd.read_csv('carbon_nanotubes.csv')
# Out:
#                                                      Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'
# 2;1;0  679005;0 701318;0 017033;0 721039;0 730232;0                                            17014.0
#        717298;0 642129;0 231319;0 738414;0 65675;0                                            232369.0
#        489336;0 303751;0 088462;0 477676;0 263221;0                                            88712.0
#        413957;0 632996;0 040843;0 408823;0 657897;0                                            39796.0
#        334292;0 543401;0 15989;0  303349;0 558807;0                                           157373.0
# ...                                                                                                ...
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CE08-50A1
#
#  Directory of C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron
#
# 23/09/2022  01:42 PM    <DIR>          .
# 23/09/2022  01:42 PM    <DIR>          ..
# 22/09/2022  09:30 PM    <DIR>          .ipynb_checkpoints
# 21/08/2022  04:27 PM    <DIR>          __pycache__
# 10/08/2022  09:56 PM            69,297 1) Python basic_String_list_Indexing.ipynb
# 16/09/2022  07:25 AM            71,909 10) MongoDB.ipynb
# 17/09/2022  05:49 PM            19,322 10.1) Mongodb exercise.ipynb
# 21/09/2022  08:51 PM            74,018 11) SQL Lite, Map, Reduce, filter, zip.ipynb
# 23/09/2022  11:41 AM            16,871 12) Pandas.ipynb
# 10/08/2022  10:02 PM            50,566 2) Tuple, Set Dict.ipynb
# 10/08/2022  10:43 PM           226,340 3) 19Dec_Python Prog Discussion.ipynb
# 10/08/2022  10:58 PM            28,649 4) Function_23Dec21.ipynb
# 10/08/2022  11:34 PM            53,772 5) Function_Part2_8Jan22.ipynb
# ...

# %%
pd.read_csv('C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\locations.csv')
# Out:
#   File "<ipython-input-5-460f0cc46c05>", line 1
#     pd.read_csv('C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\locations.csv')
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
#with the above error, we observed unicode error can be solved by having the r in front
pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\locations.csv')
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df = pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\taxonomy.csv')

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#instead of treating the 1st row as column header, we can do offset that
pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\taxonomy.csv', header=None)
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
#Created own column names

pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\taxonomy.csv', names=['a', 'b', 'c', 'd'])
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
#for example if given 3 column names for 4 column, then 1st column treated as Row Indexes
#look the 1st column as row indexes
pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\taxonomy.csv', names = ['a', 'b', 'c'])
# Out:
#                                         a          b                     c
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
#what if i give only 2 column names for 4 columns
#1st 2 column has treated as row indexex
pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\taxonomy.csv', names = ['a', 'b'])
# Out:
#                                                   a                     b
# taxonomy_id name                          parent_id           parent_name
# 101         Emergency                           NaN                   NaN
# 101-01      Disaster Response                   101             Emergency
# 101-02      Emergency Cash                      101             Emergency
# 101-02-01   Help Pay for Food                101-02        Emergency Cash
# ...                                             ...                   ...
# 111-01-07   Workplace Rights                 111-01  Advocacy & Legal Aid
# 111-02      Mediation                           111                 Legal
# 111-03      Notary                              111                 Legal
# 111-04      Representation                      111                 Legal
# 111-05      Translation & Interpretation        111                 Legal
#
# [291 rows x 2 columns]

# %%
#i have replaced ',' to '@'
pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\taxonomy.csv')
# Out:
#                 taxonomy_id@name@parent_id@parent_name
# 0                                      101@Emergency@@
# 1               101-01@Disaster Response@101@Emergency
# 2                  101-02@Emergency Cash@101@Emergency
# 3    101-02-01@Help Pay for Food@101-02@Emergency Cash
# 4    101-02-02@Help Pay for Healthcare@101-02@Emerg...
# ..                                                 ...
# 285  111-01-07@Workplace Rights@111-01@Advocacy & L...
# 286                         111-02@Mediation@111@Legal
# 287                            111-03@Notary@111@Legal
# 288                    111-04@Representation@111@Legal
# 289      111-05@Translation & Interpretation@111@Legal
#
# [290 rows x 1 columns]

# %%
#to separate the @ and read use the sep function
pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\taxonomy.csv', sep='@')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df = pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\taxonomy.csv', sep='@', skiprows=[1,3,5])

# %%
#we skipped 3 rows then the the total row is 287
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0        101-01             Disaster Response       101             Emergency
# 1     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 2     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# 3     101-02-04              Help Pay for Gas    101-02        Emergency Cash
# 4     101-02-05           Help Pay for School    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 282   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 283      111-02                     Mediation       111                 Legal
# 284      111-03                        Notary       111                 Legal
# 285      111-04                Representation       111                 Legal
# 286      111-05  Translation & Interpretation       111                 Legal
#
# [287 rows x 4 columns]

# %%
#type of each columns
df.dtypes
# Out:
# taxonomy_id    object
# name           object
# parent_id      object
# parent_name    object
# dtype: object

# %%
df = pd.read_csv(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\services.csv')

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
#top 5 rows
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
#tail 5 rows(bottom)
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
#to see all the columns
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#to see only interested columns
a = df['keywords']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [raw]
# series is nothing but a list, it could be single row or column in the dataframe
# if multiple series is joined together it is called dataframe

# %%
 df1= df[['name','keywords']]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
 df2= df[['name']]

# %%
type(df2)
#why is it dataframe? reason we have given 1 items inside the list and it return as dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CE08-50A1
#
#  Directory of C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron
#
# 23/09/2022  04:31 PM    <DIR>          .
# 23/09/2022  04:31 PM    <DIR>          ..
# 22/09/2022  09:30 PM    <DIR>          .ipynb_checkpoints
# 21/08/2022  04:27 PM    <DIR>          __pycache__
# 10/08/2022  09:56 PM            69,297 1) Python basic_String_list_Indexing.ipynb
# 16/09/2022  07:25 AM            71,909 10) MongoDB.ipynb
# 17/09/2022  05:49 PM            19,322 10.1) Mongodb exercise.ipynb
# 21/09/2022  08:51 PM            74,018 11) SQL Lite, Map, Reduce, filter, zip.ipynb
# 23/09/2022  04:31 PM           207,569 12) Pandas.ipynb
# 10/08/2022  10:02 PM            50,566 2) Tuple, Set Dict.ipynb
# 10/08/2022  10:43 PM           226,340 3) 19Dec_Python Prog Discussion.ipynb
# 10/08/2022  10:58 PM            28,649 4) Function_23Dec21.ipynb
# 10/08/2022  11:34 PM            53,772 5) Function_Part2_8Jan22.ipynb
# ...

# %%
df = pd.read_excel(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\LUSID Excel - Manage Orders.xlsx',sheet_name="Allocations")

# %%
df
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
#to know about the list of sheets in the excel file
#because the data saved in the excel file is key:value format
#where key is the sheet names and values are the data in the sheet.

df = pd.ExcelFile(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    gf = pd.read_excel(r'C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\LUSID Excel - Manage Orders.xlsx', sheet_name = i)
    print(gf, end='\n')
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-d4d4f006799c> in <module>
# ----> 1 pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
#parser error on top is avoided by using the raw data address to access

pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a =r"C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files"
b = '\services.csv'
c = a+b
print(c)
pd.read_csv(c)
# Out:
# C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron\sample csv files\services.csv
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CE08-50A1
#
#  Directory of C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron
#
# 26/09/2022  10:16 PM    <DIR>          .
# 26/09/2022  10:16 PM    <DIR>          ..
# 22/09/2022  09:30 PM    <DIR>          .ipynb_checkpoints
# 21/08/2022  04:27 PM    <DIR>          __pycache__
# 10/08/2022  09:56 PM            69,297 1) Python basic_String_list_Indexing.ipynb
# 16/09/2022  07:25 AM            71,909 10) MongoDB.ipynb
# 17/09/2022  05:49 PM            19,322 10.1) Mongodb exercise.ipynb
# 21/09/2022  08:51 PM            74,018 11) SQL Lite, Map, Reduce, filter, zip.ipynb
# 26/09/2022  10:16 PM           337,973 12) Pandas.ipynb
# 10/08/2022  10:02 PM            50,566 2) Tuple, Set Dict.ipynb
# 10/08/2022  10:43 PM           226,340 3) 19Dec_Python Prog Discussion.ipynb
# 10/08/2022  10:58 PM            28,649 4) Function_23Dec21.ipynb
# 10/08/2022  11:34 PM            53,772 5) Function_Part2_8Jan22.ipynb
# ...

# %% [raw]
# DATA Manipulation:

# %% [raw]
# Extract tabular data info from the internet page/Webpage
#
# HTML: read html only extract the webpage tabular format /table tag(tr) data other than it excludes
# scraping is important and data is stored in webpageas table or images

# %%
df= pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
#below df is not readable forma
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      675 non-null    object
#  1   Player  675 non-null    object
#  2   Pos     675 non-null    object
#  3   Age     675 non-null    object
#  4   Tm      675 non-null    object
#  5   G       675 non-null    object
#  6   GS      675 non-null    object
#  7   MP      675 non-null    object
#  8   FG      675 non-null    object
#  9   FGA     675 non-null    object
#  10  FG%     673 non-null    object
#  11  3P      675 non-null    object
#  12  3PA     675 non-null    object
#  13  3P%     594 non-null    object
#  14  2P      675 non-null    object
#  15  2PA     675 non-null    object
#  16  2P%     671 non-null    object
#  17  eFG%    673 non-null    object
#  18  FT      675 non-null    object
#  19  FTA     675 non-null    object
#  20  FT%     650 non-null    object
# ...

# %%
df1[['Age', "GS"]]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
#store the data in csv format
df1.to_csv("NBA.csv",index=False )

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CE08-50A1
#
#  Directory of C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron
#
# 26/09/2022  10:58 PM    <DIR>          .
# 26/09/2022  10:58 PM    <DIR>          ..
# 22/09/2022  09:30 PM    <DIR>          .ipynb_checkpoints
# 21/08/2022  04:27 PM    <DIR>          __pycache__
# 10/08/2022  09:56 PM            69,297 1) Python basic_String_list_Indexing.ipynb
# 16/09/2022  07:25 AM            71,909 10) MongoDB.ipynb
# 17/09/2022  05:49 PM            19,322 10.1) Mongodb exercise.ipynb
# 21/09/2022  08:51 PM            74,018 11) SQL Lite, Map, Reduce, filter, zip.ipynb
# 26/09/2022  10:58 PM           376,105 12) Pandas.ipynb
# 10/08/2022  10:02 PM            50,566 2) Tuple, Set Dict.ipynb
# 10/08/2022  10:43 PM           226,340 3) 19Dec_Python Prog Discussion.ipynb
# 10/08/2022  10:58 PM            28,649 4) Function_23Dec21.ipynb
# 10/08/2022  11:34 PM            53,772 5) Function_Part2_8Jan22.ipynb
# ...

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
l
# Out:
# [               Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
#  0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
#  1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
#  2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
#  3      Arshdeep Singh  2022-2022   11    3  3     4   2*      -    3  133.33
#  4            R Ashwin  2010-2022   56   14  9   161  31*  32.20  138  116.66
#  ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
#  94      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
#  95  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
#  96           SA Yadav  2021-2022   31   29  4   926  117  37.04  530  174.71
#  97           UT Yadav  2012-2022    8    1  0     2    2   2.00    4   50.00
#  98       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#     100 50  0  4s  6s
# ...

# %%
#how many tables in the website
len(l)
# Out:
# 3

# %%
l[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3      Arshdeep Singh  2022-2022   11    3  3     4   2*      -    3  133.33
# 4            R Ashwin  2010-2022   56   14  9   161  31*  32.20  138  116.66
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 94      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 95  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 96           SA Yadav  2021-2022   31   29  4   926  117  37.04  530  174.71
# 97           UT Yadav  2012-2022    8    1  0     2    2   2.00    4   50.00
# 98       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# ...

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Australia at Hyderabad (Deccan), 3rd T...
# 2  India v Australia at Nagpur, 2nd T20I, Sep 23,...
# 3  India v Australia at Mohali, 1st T20I, Sep 20,...

# %%
l[0].to_csv("cricket.csv", index = False)

# %%
# """this is a multi line comment or docstring"""

d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
#convert the d into datatype format / tabular format
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-85e3976986c7> in <module>
#       1 #convert the d into datatype format / tabular format
# ----> 2 pd.DataFrame(d)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
type(d)
# Out:
# str

# %%
#cannot convert directly, first convert into JSON format>document format
import json

# %% [raw]
# Online JSON viewer:
# http://jsonviewer.stack.hu/#http://
#
# when you have the data, need to validate before use (check for any error) json file system

# %%
#before convert to json format, type of d is str
result = json.loads(d)

# %%
result
# Out:
# {'name': 'Sudhanshu kumar',
#  'email id ': 'sskumar@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)

#key treated as column and Value treated as data(ROW)
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %%
pd.DataFrame(result['name'])
#why is it not working? reason: name is a str format and convert to dataframe format is not possible
# name is a str type (sudhanshu)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-eb30885eb967> in <module>
# ----> 1 pd.DataFrame(result['name'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame(result['tech'])

#why is it working? reason: tech is a list format and seay to convert to dataframe format
# tech is a list type ['ML', 'DL', 'CV']
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
result['tech'] # tech is the key when called value will be output
# Out:
# ['ML', 'DL', 'CV']

# %%
#this is dict with nested dict
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# ...

# %%
#To see the dict of nested dict
d['data'] # data is a dict in a d
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d['data'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-13f6de2da64a> in <module>
# ----> 1 pd.DataFrame(d['data'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %% [raw]
# #is it possible to convert dict into a dataframe? Yes it is possible
#
# then why there is a ValueError: arrays must all be same length, some of the arrays are different length or not equal
#
# Below is the data which are not equal?
# diagnosticTroubleCodeData': []
# contains the empty list, because we need same length
#
# What can we do now? del or drop the data
# diagnosticTroubleCodeData': []

# %%
d1 = d['data']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
#cannot assign the delete operation
d1 = del d1['diagnosticTroubleCodeData']
# Out:
#   File "<ipython-input-21-a322fcf59a3b>", line 1
#     d1 = del d1['diagnosticTroubleCodeData']
#            ^
# SyntaxError: invalid syntax

# %%
#delete the key and value
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %% [raw]
# Nested json and nested json inside: structured format
#
# url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
#convert this url into dataframe format
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
#read json file (url repositories)
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %% [raw]
# question: get the user ID from the json file? json in a json format
# now current json file(url), having data inside in another data (kind of nested json in nested json)
# but listing as url links, what we need is raw data from the url links instead of links
#
# 1) Just load into raw json data > to do that request method, will get the url data
# 2) pass the url
# 3) data.json()
#
# How many unique dict available or key? len(data1) > 30
#
# how do we get the user from unique dict?

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48805',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48805/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48805/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48805/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48805',
#   'id': 1387090446,
#   'node_id': 'PR_kwDOAA0YD84_qPpH',
#   'number': 48805,
#   'title': 'Added padding and fixed columns for sponsor logos in mobile view',
#   'user': {'login': 'amay-patel',
#    'id': 92037532,
#    'node_id': 'U_kgDOBXxhnA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92037532?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amay-patel',
#    'html_url': 'https://github.com/amay-patel',
# ...

# %%
len(data1)
# Out:
# 30

# %%
#filter out 1 unique data, 1st data
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48805',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48805/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48805/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48805/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/48805',
#  'id': 1387090446,
#  'node_id': 'PR_kwDOAA0YD84_qPpH',
#  'number': 48805,
#  'title': 'Added padding and fixed columns for sponsor logos in mobile view',
#  'user': {'login': 'amay-patel',
#   'id': 92037532,
#   'node_id': 'U_kgDOBXxhnA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92037532?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/amay-patel',
#   'html_url': 'https://github.com/amay-patel',
#   'followers_url': 'https://api.github.com/users/amay-patel/followers',
# ...

# %%
#filter out 1 unique data, 1st data
data1[29]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48762',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48762/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48762/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48762/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/48762',
#  'id': 1384767079,
#  'node_id': 'I_kwDOAA0YD85Sid5n',
#  'number': 48762,
#  'title': 'DOC: Update color of icons for dark theme',
#  'user': {'login': 'datapythonista',
#   'id': 10058240,
#   'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/datapythonista',
#   'html_url': 'https://github.com/datapythonista',
# ...

# %%
data1[0]['user']['id']
# Out:
# 92037532

# %%
#fetch all the user ID 
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 92037532
# 10647082
# 31753237
# 48577571
# 39504233
# 12621235
# 1804856
# 39504233
# 516999
# 45562402
# 596279
# 13767301
# 22385371
# 7980666
# 5585221
# 33491632
# 33491632
# 28426758
# 51007145
# 114391084
# 61934744
# 5946712
# 12532395
# 76431630
# 4675524
# 33796896
# 113800322
# 175722
# 1675613
# 10058240

# %%
#how to fetch few columns from the data
df2 = pd.DataFrame(data1, columns=['url','repository_url', 'labels_url', 'user'])

# %%
df2.to_csv('json.csv')

# %%
pd.DataFrame(data1)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#split the user column data into individual columns and fill in the values
def usersplit(data1[user]):
    if data1[user]== list or data1[user]==dict:
# Out:
#   File "<ipython-input-45-137ef13cbaf9>", line 1
#     def usersplit(data1[user]):
#                        ^
# SyntaxError: invalid syntax

# %%
pd.DataFrame(data1, )
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %% [markdown]
# # Day3: 5th Mar 2022 - Dataframe Analysis

# %%
import pandas as pd

# %%
#read the github titanic data
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [raw]
# 1) try to find out what is the meaning of the database, attributes and do the required actions like statistics
# 2) understand the database first
# 3) df.info(), by looking the data find out there is a null values compared to other columns
# 4) Pre-processing the data EDA: null values / missing value need to handle either exclude, give data value
# 5) describe the database (Statistics)
#     Standard deviation : dispersion from mean value
#     ex: mean is $50, STD is $2, now the $2 is the difference between train and flight ticket. In this case which ticket, will you book? Flight ticket because the dispersion from mean is only $2, so $50+$2 = $52 for flight.
#
#     Variance: bike speed(0 10, 80, 100, 20, 40)
#     what is the variance of the speed is 0-100
#
#     what is 25%, 50%, 75% percentile?
#     ex: 1,2,4,6,8,10,11,12,16,8,3,1
#     arrange in ascending order
#     1,1,2,3,4,6,8,8,10,11,12,16
#     min=1(0th percentile is index 0), max=16(100th percentile)
#     what is 25%? total 12 data, 25th percentile in this data is index 3
#     50% is 6th index
#     75% is 9th index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
l= [1,2,4,6,8,10,11,12,16,8,3,1]
c= pd.Series(l)

# %%
c.sort_values()
# Out:
# 0      1
# 11     1
# 1      2
# 10     3
# 2      4
# 3      6
# 4      8
# 9      8
# 5     10
# 6     11
# 7     12
# 8     16
# dtype: int64

# %%
c
# Out:
# 0      1
# 1      2
# 2      4
# 3      6
# 4      8
# 5     10
# 6     11
# 7     12
# 8     16
# 9      8
# 10     3
# 11     1
# dtype: int64

# %%
c.describe()
# Out:
# count    12.000000
# mean      6.833333
# std       4.821040
# min       1.000000
# 25%       2.750000
# 50%       7.000000
# 75%      10.250000
# max      16.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [raw]
# How to find out the describe for object type?
# 1. select only the data types which is Object
# 2. use this as a filter to filter out from the entire df
# 3. then find the describe

# %%
df.dtypes =='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
col_name = df.dtypes[df.dtypes=='object'].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[col_name].describe()
# Out:
#                                Name   Sex    Ticket    Cabin Embarked
# count                           891   891       891      204      889
# unique                          891     2       681      147        3
# top     Goodwin, Mr. Charles Edward  male  CA. 2343  B96 B98        S
# freq                              1   577         7        4      644

# %% [raw]
# By looking the categories describe info
# 1. name is unique and all different
# 2. sex is male and female
# 3. ticket, 681 are unique and few are travelled in 1 ticket
# 4. cabin, 147 is unique ..

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#add new column
df['ineuron'] = "mohan"

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked ineuron
# 0      0         A/5 21171   7.2500   NaN        S   mohan
# 1      0          PC 17599  71.2833   C85        C   mohan
# 2      0  STON/O2. 3101282   7.9250   NaN        S   mohan
# 3      0            113803  53.1000  C123        S   mohan
# ...

# %%
#list only the 15 name
df['Name'].head(15)
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][::-1]
# Out:
# 890                                  Dooley, Mr. Patrick
# 889                                Behr, Mr. Karl Howell
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 887                         Graham, Miss. Margaret Edith
# 886                                Montvila, Rev. Juozas
#                              ...
# 4                               Allen, Mr. William Henry
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                                 Heikkinen, Miss. Laina
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 0                                Braund, Mr. Owen Harris
# Name: Name, Length: 891, dtype: object

# %%
#find null records are not? filter out the index number
df['Age'].isnull()==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isnull()==True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
len(df[df['Age'].isnull()==True].index)
# Out:
# 177

# %%
#select only the null value indexes
ind = df[df['Age'].isnull()==True].index

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df['Age'].isnull()==True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#find out person name, who has paid highest fair
df['Fare'].max()
# Out:
# 512.3292

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     ineuron
# 258   mohan
# 679   mohan
# 737   mohan

# %%
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %% [raw]
# 1. Find out how many male and female boarded?
# 2. How many have survived?
# 3. how many causuality we have?
# 4. what is the name of a passenger who is eldest one.
# 5. how many person do we have in 1st, 2nd or 3rd class
# 6. How many person we have hose name start with 's'
# 7. try to create a new column which is a summation of "sibsp" and 'Parch'
# 8 . how many person do we have below age of 25 .
# 9 . how many person died whose age was less then 40
# 10 . from a  cabin column seperate text and numeric value .

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 1. Find out how many male and female boarded?
m = len(df[df['Sex']=='male'])

f = len(df[df['Sex']=='female'])
print("male: ", m, "female: ", f)
# Out:
# male:  577 female:  314

# %%
print("Number of male %s and female %s" %(m, f,) )
# Out:
# Number of male 577 and female 314

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
# 2. How many have survived?
s = len(df[df['Survived']==1])
print("survived: ", s)
# Out:
# survived:  342

# %%
# 3. how many causuality we have?
c = len(df[df['Survived']==0])
print("survived: ", c)
# Out:
# survived:  549

# %%
# 4. what is the name of a passenger who is eldest one.
df[df['Age']==max(df['Age'])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
# 4. what is the name of a passenger who is eldest one.
# df['Age'].max() we know the Age =80 use this as filter
# df['Age'] == df['Age'].max() this will do true or false in the whole dataframe, substitude this in the dataframe
# df[df['Age'] == df['Age'].max()] with this filter out the name only.
df[df['Age'] == df['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
# 5. how many person do we have in 1st, 2nd or 3rd class
print("1st class:", len(df[df['Pclass']==1]), "2nd class:", len(df[df['Pclass']==2]),"3rd class:", len(df[df['Pclass']==3]))
# Out:
# 1st class: 216 2nd class: 184 3rd class: 491

# %%
df.groupby(['Pclass']).size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# 6. How many person we have those name start with 's'
n = []
for i in df["Name"]:
    if(i[0] == 'S'):
        n.append(i)

print("name of the person start with 's'", n)
# Out:
# name of the person start with 's' ['Sandstrom, Miss. Marguerite Rut', 'Saundercock, Mr. William Henry', 'Sloper, Mr. William Thompson', 'Spencer, Mrs. William Augustus (Marie Eugenie)', 'Samaan, Mr. Youssef', 'Sirayanian, Mr. Orsen', 'Skoog, Master. Harald', 'Stewart, Mr. Albert A', 'Staneff, Mr. Ivan', 'Sheerlinck, Mr. Jan Baptist', 'Slocovski, Mr. Selman Francis', 'Shorney, Mr. Charles Joseph', 'Salkjelsvik, Miss. Anna Kristine', 'Sobey, Mr. Samuel James Hayden', 'Smiljanic, Mr. Mile', 'Sage, Master. Thomas Henry', 'Skoog, Mrs. William (Anna Bernhardina Karlsson)', 'Sivola, Mr. Antti Wilhelm', 'Smith, Mr. James Clinch', 'Sage, Miss. Constance Gladys', 'Sage, Mr. Frederick', 'Strom, Miss. Telma Matilda', 'Sunderland, Mr. Victor Francis', 'Sjostedt, Mr. Ernst Adolf', 'Strom, Mrs. Wilhelm (Elna Matilda Persson)', 'Stead, Mr. William Thomas', 'Smith, Mr. Thomas', 'Smith, Mr. Richard William', 'Stankovic, Mr. Ivan', 'Saalfeld, Mr. Adolphe', 'Spedden, Mrs. Frederic Oakley (Margaretta Cor
# ...

# %%
s=df[df['Name'].str.startswith('S')]['Name'] #.str is convert the series to string format

# %%
s.to_csv('Sname')

# %%
len(s)
# Out:
# 86

# %%
type(df['Name']) #it is a series
# Out:
# pandas.core.series.Series

# %%
len(df['Name'][(df['Name'].str.startswith('S') | df['Name'].str.startswith('s'))])
# Out:
# 86

# %%
# 7. try to create a new column which is a summation of "sibsp" and 'Parch'
df["sib+Par"] = df["SibSp"]+df["Parch"]

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  sib+Par
# 0      0  A/5 21171   7.2500   NaN        S        1
# 1      0   PC 17599  71.2833   C85        C        1

# %%
# 8 . how many person do we have below age of 25 .
l = len(df[df['Age']<25])
print("age less than 25: ", l)
# Out:
# age less than 25:  278

# %%
# 9 . how many person died whose age was less then 40 
l40 = df[df['Age']<40]

# %%
l40 # database filtered with <40 age
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
le40 = len(l40[l40['Survived']==0])
print("Those who died less than 40: ", le40)
# Out:
# Those who died less than 40:  322

# %%
# 10 . from a  cabin column seperate text and numeric value . 
len(df[df['Cabin'].isnull()])
# Out:
# 687

# %%
import re

# %%
# help(re)

# %%
expression = re.compile("([a-zA-Z]+)") #expression defined as "a-z then A-Z +(other object)"

df['Cabin_string'] = df['Cabin'].str.extract(expression) # str extract with expression
df['Cabin_number'] = df['Cabin'].str.replace(expression, "") #str replace with expression and assign null value

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = pd.DataFrame(df['Cabin'].str.split('([a-zA-z]+)([^a-zA-z]+)')) # ^ is a not function

df2.columns
df2
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 85, ]
# 2             NaN
# 3    [, C, 123, ]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 42, ]
# 888           NaN
# 889  [, C, 148, ]
# 890           NaN
#
# [891 rows x 1 columns]

# %%
df['cabinNum'] = df['Cabin'].str.replace('([a-zA-z]+)', '')
df['cabinLet'] = df['Cabin'].str.extract('([a-zA-z]+)')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked cabinNum cabinLet
# 0      0         A/5 21171   7.2500   NaN        S      NaN      NaN
# 1      0          PC 17599  71.2833   C85        C       85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S      NaN      NaN
# ...

# %% [raw]
# regular expression
#
# Resumes in iNeuron:
#     https://github.com/iNeuronai
#
#         download
#         read out all data in resume
#         check email or name or github or not
#
# Task:
#
# read all the resume from github in pdf, in word, and try to create a dataframe with resume name
# as a index value, and in column. I am expecting email ID, linkedin ID, skills as a result
#
# Need to write 3 regular expression to filter out the email, github and linkedin column.
#
# there are many pythonic code for reading pdf, docx..

# %%
import pandas as pd

# %% [markdown]
# # Banking Task

# %%
#dataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing

import pandas as pd
df = pd.read_csv('C:\\2022\\Personnal\\Learning\\iNeuron\\Pandas_Exercisefile\\bank\\bank.csv', sep=";")

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [raw]
# 1 . how many campaign available in this dataset .
# 2 . how many users do we have with housing and personal loan .
# 3. how many person do we have whose age is 60+ .
# 4 . in which month we have trageted most of the customer .
# 5 . which mode of call is giving you more result
# 6 . how many enterpeures do we have in this list
# 7 . how many customers do we have with negative balance
# 8. prepare a group of data based on education level .

# %%
# 1 . how many campaign available in this dataset . 
len(df['campaign'].unique())
# Out:
# 32

# %% [raw]
# other ways are
# # df['campaign'] # as list
# list(df['campaign']) then convert to set (is for unique no)
# then find the len of it

# %%
number_of_campaigns = df['campaign'].unique().size
print('Number of campaigns available:', number_of_campaigns)
# Out:
# Number of campaigns available: 32

# %%
# 2 . how many users do we have with housing and personal loan . 
userwithloans = len(df[(df['housing']=='yes') & (df['loan']=='yes')])
print('users with personal and housing loan: ', userwithloans)
# Out:
# users with personal and housing loan:  406

# %%
# for example filter out those who dont have any loan? with that loan we can see what are th options to approach them for sancation loan for car, investment et.
userwithoutloans = df[(df['housing']!='yes') & (df['loan']!='yes')]
userwithoutloans
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 5      35   management    single   tertiary      no      747      no   no
# 12     36   technician   married   tertiary      no     1109      no   no
# 13     20      student    single  secondary      no      502      no   no
# 16     56   technician   married  secondary      no     4073      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4506   42   unemployed  divorced   tertiary      no     -166      no   no
# 4509   51   technician   married   tertiary      no     2506      no   no
# 4513   49  blue-collar   married  secondary      no      322      no   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
# 3. how many person do we have whose age is 60+ . 
age60 = len(df[df['age']>60])
print('age more than 60: ', age60)
# Out:
# age more than 60:  127

# %%
# 4 . in which month we have trageted most of the customer .
df['month'].value_counts().head(1)
# Out:
# may    1398
# Name: month, dtype: int64

# %%
df.groupby(df['month']).size().sort_values(ascending=False).head(1)
# Out:
# month
# may    1398
# dtype: int64

# %%
df['month'].value_counts().sort_values(ascending=False).head(1)
# Out:
# may    1398
# Name: month, dtype: int64

# %%
#5 . which mode of call is giving you more result
df.groupby(df['contact']).size().sort_values(ascending=False).head(1)
# Out:
# contact
# cellular    2896
# dtype: int64

# %%
df['contact'].value_counts().head(1)
# Out:
# cellular    2896
# Name: contact, dtype: int64

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df4 = df.groupby(['contact', 'y']).size()

# %%
#groupby list down how many have grouped based on list of columns
df.groupby(['contact', 'y']).count()
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
#groups give you the index no of group by columns
df.groupby(['contact', 'y']).groups
# Out:
# {('cellular',
#   'no'): Int64Index([   0,    1,    2,    5,    6,    7,    9,   11,   12,   14,
#              ...
#              4506, 4507, 4509, 4513, 4514, 4515, 4516, 4518, 4519, 4520],
#             dtype='int64', length=2480),
#  ('cellular',
#   'yes'): Int64Index([  13,   33,   34,   37,   38,   49,   53,   70,   80,   84,
#              ...
#              4407, 4416, 4423, 4433, 4447, 4458, 4465, 4484, 4503, 4504],
#             dtype='int64', length=416),
#  ('telephone',
#   'no'): Int64Index([  27,   46,   55,   56,   60,  102,  103,  111,  128,  166,
#              ...
#              4359, 4383, 4435, 4437, 4439, 4443, 4446, 4468, 4474, 4495],
#             dtype='int64', length=257),
#  ('telephone',
#   'yes'): Int64Index([  30,   36,   83,  114,  199,  204,  382,  443,  477,  492, 1025,
#              1056, 1312, 1349, 1435, 1534, 1739, 1889, 1952, 2032, 2148, 2499,
#              2773, 2821, 2827, 3176, 3202, 3333, 3360, 3491, 3540, 3658, 3743,
# ...

# %%
#cellular contact: NO from index 1
df.iloc[1]
# Out:
# age                 33
# job           services
# marital        married
# education    secondary
# default             no
# balance           4789
# housing            yes
# loan               yes
# contact       cellular
# day                 11
# month              may
# duration           220
# campaign             1
# pdays              339
# previous             4
# poutcome       failure
# y                   no
# Name: 1, dtype: object

# %%
#cellular contact: YES from index 13
df.iloc[13]
# Out:
# age                 20
# job            student
# marital         single
# education    secondary
# default             no
# balance            502
# housing             no
# loan                no
# contact       cellular
# day                 30
# month              apr
# duration           261
# campaign             1
# pdays               -1
# previous             0
# poutcome       unknown
# y                  yes
# Name: 13, dtype: object

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df4
# Out:
# contact    y
# cellular   no     2480
#            yes     416
# telephone  no      257
#            yes      44
# unknown    no     1263
#            yes      61
# dtype: int64

# %%
df4.loc['cellular', 'yes']
# Out:
# 416

# %%
df4.loc['telephone', 'yes']
# Out:
# 44

# %%
max(df4.loc['cellular', 'yes'],df4.loc['telephone', 'yes'],df4.loc['unknown', 'yes'])
# Out:
# 416

# %%
#6 . how many enterpeures do we have in this list  
len(df.groupby(df['job']).get_group("entrepreneur"))
# Out:
# 168

# %%
len(df[df['job']=='entrepreneur'])
# Out:
# 168

# %%
e = df['job'].value_counts()

# %%
e
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
e['entrepreneur']
# Out:
# 168

# %%
#7 . how many customers do we have with negative balance 
len(df[df['balance']<0])
# Out:
# 366

# %%
neg_bal = len(df[df['balance']<0])
print("no. of customer with negative balance:", neg_bal)
# Out:
# no. of customer with negative balance: 366

# %%
#8. prepare a group of data based on education level .
df.groupby(df['education']).size()
# Out:
# education
# primary       678
# secondary    2306
# tertiary     1350
# unknown       187
# dtype: int64

# %%
df['education'].value_counts()
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
g = df.groupby(df['education'])

# %%
g.size()
# Out:
# education
# primary       678
# secondary    2306
# tertiary     1350
# unknown       187
# dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
print("pandas version:", pd.__version__)
print("numpy version: ", np.__version__)
# Out:
# pandas version: 1.0.1
# numpy version:  1.18.1

# %%
df['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
#8. prepare a group of dataase based on education level.
edu = []
for i in df['education'].unique():
    edu.append(df[df['education']==i])

# %%
edu[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
edu[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
edu[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...
