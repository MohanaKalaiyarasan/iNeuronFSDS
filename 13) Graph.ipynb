# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.DataFrame(np.random.randn(1000), columns=['data'], index=pd.date_range('2022-12-10', periods = 1000))

# %%
df
# Out:
#                 data
# 2022-12-10 -1.059534
# 2022-12-11 -0.268226
# 2022-12-12 -1.190690
# 2022-12-13 -1.114689
# 2022-12-14 -1.163980
# ...              ...
# 2025-08-31  0.363557
# 2025-09-01  1.102942
# 2025-09-02  0.093576
# 2025-09-03  0.362227
# 2025-09-04  1.703349
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,10)) #2 D axis graph

# %%
#iris dataset from GIT, get as raw
df = pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
species = df.groupby('Species').count()

# %%
species
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa      50             50            50             50            50
# Iris-versicolor  50             50            50             50            50
# Iris-virginica   50             50            50             50            50

# %%
df.plot(figsize = (20,10))

# %%
df = df.drop('Id', axis =1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize = (20,10))

# %%
df.plot(kind = 'bar', figsize=(20,10)) #default kind of chart is line

# %%
df[5:11].plot(kind = 'bar', figsize = (20,10)) #slicing

# %%
df.iloc[5:11].plot(kind = 'bar', figsize = (20,10)) #by iloc

# %%
df.iloc[5:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df.iloc[[5]].plot(kind = 'barh', figsize = (20,10)) # bar horizontal

# %%
df.iloc[5:11].plot(kind = 'barh', figsize = (20,10))

# %%
df.plot(kind = 'hist', figsize = (20,10))  #histogram

# %%
#with one column
df['SepalLengthCm'].plot(kind = 'hist')

# %%
df['SepalLengthCm'].plot(kind = 'hist',orientation = 'horizontal')

# %%
#whole dataframe is in histogram
df.hist(figsize = (20,10), color = 'g', alpha = 0.2) # alpha is the intesity of color
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019FCD1B94C8>,
# ...
#       dtype=object)

# %%
#boxplot
df.plot(kind = 'box', figsize = (20,10))

# %% [raw]
# use of box plot is to find out the outlier in the dataframe.

# %%
#vertical box plot
df.plot(kind = 'box' ,figsize = (20,10),color = {'boxes' : 'g' , 'whiskers' :'r'} , vert = False )

# %%
#area Plot
df.plot(kind = "area", figsize =(20,10), alpha = 0.5, stacked = False)

# %%
#Stacked = True,one on another kind of stacked chart. 
df.plot(kind = "area", figsize =(20,10), alpha = 0.5, stacked = True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#scatter plot, need 2 axis data
df.plot.scatter(x ='SepalLengthCm', y = 'PetalLengthCm' )

# %%
df.plot.scatter(x ='SepalLengthCm', y = 'PetalWidthCm' )

# %%
#scatter plot with 3 axis, c axis is a color axis
df.plot.scatter(x ='SepalLengthCm', y = 'PetalLengthCm', c = 'SepalWidthCm' )

# %%
#s is a size of the petals width
df.plot.scatter(x ='SepalLengthCm', y = 'PetalLengthCm', c = 'SepalWidthCm', s = 600 )

# %%
#s is defined with PetalWidthCm
df.plot.scatter(x ='SepalLengthCm', y = 'PetalLengthCm', c = 'SepalWidthCm', s = df['PetalWidthCm']*600 )

# %%
df.plot.hexbin(x='SepalLengthCm', y = 'PetalLengthCm', gridsize = 10, C ='SepalWidthCm')

# %%
df.iloc[0]
# Out:
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
#for Pie chart, remove the categories column
df1 = df.drop(columns='Species').iloc[0]

# %%
df1
# Out:
# SepalLengthCm    5.1
# SepalWidthCm     3.5
# PetalLengthCm    1.4
# PetalWidthCm     0.2
# Name: 0, dtype: float64

# %%
df1.plot(kind='pie')

# %% [raw]
# Install Plotly for interactive plot
# cufflinks is the offline version of plotly
# !pip install chart_studio - offline mode chart
# import cufflinks as cf
# cf.go_offline() - TO RUN AT OFFLINE

# %%
# !pip install plotly

# %%
pip install plotly==5.10.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = df.drop(columns = 'Id')

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import cufflinks as cf

# %%
# !pip install cufflinks

# %%
import cufflinks as cf
# !pip install chart_studio

# %%
df.iplot()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\mral\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-69813823c9f3>", line 1, in <module>
#     df.iplot()
#   File "C:\Users\mral\Anaconda3\lib\site-packages\cufflinks\plotlytools.py", line 1218, in _iplot
#     dimensions=dimensions,display_image=kwargs.get('display_image',True))
#   File "C:\Users\mral\Anaconda3\lib\site-packages\cufflinks\plotlytools.py", line 1471, in iplot
#     filename=filename)
#   File "C:\Users\mral\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py", line 135, in iplot
#     url = plot(figure_or_data, **plot_options)
#   File "C:\Users\mral\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py", line 280, in plot
#     auto_open=False,
# ...

# %%
# !pip install cufflinks
# !pip install plotly
# !pip install chart_studio

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="4bec4fac-b9fa-49f9-919c-7e90a2274252" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head(1)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
df.iplot(x='SepalLengthCm', y = 'PetalLengthCm', mode='markers', kind = 'scatter')
# Out:
# <div>                            <div id="6c7e9926-f2ec-4d5c-932c-bcaedd212f1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'scatter', mode = 'markers', size = 5)
# Out:
# <div>                            <div id="179184de-5949-4981-9d72-effdff696a62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind ='bubble', x = 'SepalLengthCm', y = 'PetalLengthCm', size = 'SepalWidthCm')
# Out:
# <div>                            <div id="2ede1edc-7bf8-43b5-8e79-96200bf66b6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="0d419b3f-8a8e-49a1-bac9-39ddf4807106" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#3D plot
df.head().iplot(kind = 'scatter3d', x = 'SepalLengthCm', y='SepalWidthCm', z='PetalLengthCm')
# Out:
# <div>                            <div id="6ae600ec-7b3b-413b-a854-e0bc8fb9275f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.iplot(kind = 'bubble3d', x = 'SepalLengthCm', y='SepalWidthCm', z='PetalLengthCm',size =  'PetalWidthCm')
# Out:
# <div>                            <div id="cbd2941e-451f-4ed3-9220-3410ad6f5e6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [raw]
# Homework -
#
# Try to explore map graph and try to show and example (2-3)
# ex: Covid data,
#  population data sources and use it plot.
# https://plotly.com/python/maps/

# %% [raw]
# Data Analytics vs Data scientist
# Analysis - solution / product to the issue
#         Python  | AI
#    SQL, Big data | ML/DL
# Power BI
# Tableau
#
# Full Stack:
# 1) Python (Assignments / coding parts)
#     1) Python lib (Pandas, Numpy, Seaborn, matplotlib, plotly, cufflinks)
#     2) Databases (Mysql, MongoDB, Cassandra)
#     3) WEB Frame (Kviy, TKinter, Flask, Django)
#     4) Gui Frame
#     5) Statistics
# 2) ML _ data predicting analysis
# 3) DL
# 4) DIOps
# 5) BA
#
# sunny.savita@ineuron.ai
