# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host="localhost", user ="root", passwd = "Surya26Sparkle$")

# %%
cursor = mydb.cursor() #pointer

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('car',),
#  ('cats',),
#  ('dogapp',),
#  ('ig_clone',),
#  ('information_schema',),
#  ('myapp',),
#  ('mysql',),
#  ('performance_schema',),
#  ('shirts_db',),
#  ('soap_store',),
#  ('sys',),
#  ('test',),
#  ('tv_review_app',)]

# %%
cursor.execute("select * from test.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
#Select some data by column name
cursor.execute('select col1, col2, col3 from test.glassdata')

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64),
#  (6, 8.0, 13.64),
#  (2, 1.51761, 13.89),
#  (3, 1.51618, 13.53),
#  (5, 1.51742, 13.27),
#  (6, 1.51596, 12.79),
#  (7, 1.51743, 13.3),
#  (8, 1.51756, 13.15),
#  (9, 1.51918, 14.04),
#  (10, 1.51755, 13.0),
#  (11, 1.51571, 12.72),
#  (12, 1.51763, 12.8),
#  (13, 1.51589, 12.88),
#  (14, 1.51748, 12.86),
#  (15, 1.51763, 12.61),
#  (16, 1.51761, 12.81),
#  (17, 1.51784, 12.68),
#  (18, 1.52196, 14.36),
#  (19, 1.51911, 13.9),
#  (20, 1.51735, 13.02),
#  (21, 1.5175, 12.82),
#  (22, 1.51966, 14.77),
#  (23, 1.51736, 12.78),
#  (24, 1.51751, 12.81),
#  (25, 1.5172, 13.38),
#  (26, 1.51764, 12.98),
#  (27, 1.51793, 13.21),
#  (28, 1.51721, 12.87),
#  (29, 1.51768, 12.56),
#  (30, 1.51784, 13.08),
#  (31, 1.51768, 12.65),
#  (32, 1.51747, 12.84),
#  (33, 1.51775, 12.85),
#  (34, 1.51753, 12.57),
#  (35, 1.51783, 12.69),
#  (36, 1.51567, 13.29),
#  (37, 1.51909, 13.89),
#  (38, 1.51797, 12.74),
#  (39, 1.52213, 14.21),
#  (40, 1.52213, 14.21),
# ...

# %%
# select the column by certain criteria with WHERE clause
cursor.execute('select *from test.glassdata WHERE col1 = 4 and col11= 1')

# %%
cursor.fetchall()
# Out:
# []

# %%
#delete the column by certain criteria
cursor.execute('delete from test.glassdata where col1=4')

# %%
mydb.commit()

# %%
cursor.execute("select *from test.glassdata")
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
#To update the data
cursor.execute("UPDATE test.glassdata SET col1=6, col2 =8 WHERE col1=1 ")

# %%
mydb.commit()

# %%
cursor.execute('select *from test.glassdata')

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cursor.execute('select *from test.glassdata WHERE col1=6')
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
#group by Operation based on certain condition
cursor.execute("select count(col1), col2 from test.glassdata group by col1")
cursor.fetchall()
# Out:
# [(3, 8.0),
#  (1, 1.51761),
#  (1, 1.51618),
#  (1, 1.51742),
#  (1, 1.51743),
#  (1, 1.51756),
#  (1, 1.51918),
#  (1, 1.51755),
#  (1, 1.51571),
#  (1, 1.51763),
#  (1, 1.51589),
#  (1, 1.51748),
#  (1, 1.51763),
#  (1, 1.51761),
#  (1, 1.51784),
#  (1, 1.52196),
#  (1, 1.51911),
#  (1, 1.51735),
#  (1, 1.5175),
#  (1, 1.51966),
#  (1, 1.51736),
#  (1, 1.51751),
#  (1, 1.5172),
#  (1, 1.51764),
#  (1, 1.51793),
#  (1, 1.51721),
#  (1, 1.51768),
#  (1, 1.51784),
#  (1, 1.51768),
#  (1, 1.51747),
#  (1, 1.51775),
#  (1, 1.51753),
#  (1, 1.51783),
#  (1, 1.51567),
#  (1, 1.51909),
#  (1, 1.51797),
#  (1, 1.52213),
#  (1, 1.52213),
#  (1, 1.51793),
#  (1, 1.51755),
#  (1, 1.51779),
#  (1, 1.5221),
#  (1, 1.51786),
#  (1, 1.519),
#  (1, 1.51869),
#  (1, 1.52667),
#  (1, 1.52223),
#  (1, 1.51898),
#  (1, 1.5232),
#  (1, 1.51926),
#  (1, 1.51808),
#  (1, 1.51837),
#  (1, 1.51778),
#  (1, 1.51769),
#  (1, 1.51215),
#  (1, 1.51824),
#  (1, 1.51754),
#  (1, 1.51754),
#  (1, 1.51905),
# ...

# %%
cursor.execute("select col1, count(col1), col11 from test.glassdata group by col1 order by col1")

# %%
cursor.fetchall()
# Out:
# [(2, 1, 1),
#  (3, 1, 1),
#  (5, 1, 1),
#  (6, 3, 1),
#  (7, 1, 1),
#  (8, 1, 1),
#  (9, 1, 1),
#  (10, 1, 1),
#  (11, 1, 1),
#  (12, 1, 1),
#  (13, 1, 1),
#  (14, 1, 1),
#  (15, 1, 1),
#  (16, 1, 1),
#  (17, 1, 1),
#  (18, 1, 1),
#  (19, 1, 1),
#  (20, 1, 1),
#  (21, 1, 1),
#  (22, 1, 1),
#  (23, 1, 1),
#  (24, 1, 1),
#  (25, 1, 1),
#  (26, 1, 1),
#  (27, 1, 1),
#  (28, 1, 1),
#  (29, 1, 1),
#  (30, 1, 1),
#  (31, 1, 1),
#  (32, 1, 1),
#  (33, 1, 1),
#  (34, 1, 1),
#  (35, 1, 1),
#  (36, 1, 1),
#  (37, 1, 1),
#  (38, 1, 1),
#  (39, 1, 1),
#  (40, 1, 1),
#  (41, 1, 1),
#  (42, 1, 1),
#  (43, 1, 1),
#  (44, 1, 1),
#  (45, 1, 1),
#  (46, 1, 1),
#  (47, 1, 1),
#  (48, 1, 1),
#  (49, 1, 1),
#  (50, 1, 1),
#  (51, 1, 1),
#  (52, 1, 1),
#  (53, 1, 1),
#  (54, 1, 1),
#  (55, 1, 1),
#  (56, 1, 1),
#  (57, 1, 1),
#  (58, 1, 1),
#  (59, 1, 1),
#  (60, 1, 1),
#  (61, 1, 1),
#  (62, 1, 1),
#  (63, 1, 1),
#  (64, 1, 1),
#  (65, 1, 1),
#  (66, 1, 1),
#  (67, 1, 1),
#  (68, 1, 1),
#  (69, 1, 1),
# ...

# %%
cursor.execute("select *from test.study")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     559                 raw_as_string=raw_as_string,
# --> 560                 query_attrs=self._query_attrs,
#     561             )
#
# MySQLInterfaceError: Table 'test.study' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-52-7145b71697b2> in <module>
# ----> 1 cursor.execute("select *from test.study")
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     278                 raw=self._raw,
#     279                 buffered=self._buffered,
# --> 280                 raw_as_string=self._raw_as_string,
# ...

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select count(*) from test.study")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     559                 raw_as_string=raw_as_string,
# --> 560                 query_attrs=self._query_attrs,
#     561             )
#
# MySQLInterfaceError: Table 'test.study' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-54-cb868de925a7> in <module>
# ----> 1 cursor.execute("select count(*) from test.study")
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     278                 raw=self._raw,
#     279                 buffered=self._buffered,
# --> 280                 raw_as_string=self._raw_as_string,
# ...

# %%
cursor.fetchall()

# %% [raw]
# if the syntax as Where clause, first it satisfies the clause(condition defined to perform in the syntax)
#
# group by just perform the condition

# %% [raw]
# SQL:
# 1) create DB
# 2) Create table
# 3) delete table (drop)
# 4) delete record
# 5) insert
# 6) update
# 7) group by
# 8) Where

# %%
#delete a table with drop command
cursor.execute('drop table test.study')
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     559                 raw_as_string=raw_as_string,
# --> 560                 query_attrs=self._query_attrs,
#     561             )
#
# MySQLInterfaceError: Unknown table 'test.study'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-55-c514308fb52a> in <module>
#       1 #delete a table with drop command
# ----> 2 cursor.execute('drop table test.study')
#       3 mydb.commit()
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     278                 raw=self._raw,
#     279                 buffered=self._buffered,
# ...

# %%
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('car',),
#  ('cats',),
#  ('dogapp',),
#  ('ig_clone',),
#  ('information_schema',),
#  ('myapp',),
#  ('mysql',),
#  ('performance_schema',),
#  ('shirts_db',),
#  ('soap_store',),
#  ('sys',),
#  ('test',),
#  ('tv_review_app',)]

# %%
#after dropped the Study table from test database

cursor.execute('show tables from test')
cursor.fetchall()
# Out:
# [('glassdata',)]

# %%
cursor.execute('select *from test.glassdata')

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
# Fetch all data where col1=11 or col11=2
cursor.execute('select col1, col2, col11 from test.glassdata where col1=11 or col11=2')
cursor.fetchall()
# Out:
# [(11, 1.51571, 1),
#  (71, 1.51574, 2),
#  (72, 1.51848, 2),
#  (73, 1.51593, 2),
#  (74, 1.51631, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
#  (77, 1.51645, 2),
#  (78, 1.51627, 2),
#  (79, 1.51613, 2),
#  (80, 1.5159, 2),
#  (81, 1.51592, 2),
#  (82, 1.51593, 2),
#  (83, 1.51646, 2),
#  (84, 1.51594, 2),
#  (85, 1.51409, 2),
#  (86, 1.51625, 2),
#  (87, 1.51569, 2),
#  (88, 1.51645, 2),
#  (89, 1.51618, 2),
#  (90, 1.5164, 2),
#  (91, 1.51841, 2),
#  (92, 1.51605, 2),
#  (93, 1.51588, 2),
#  (94, 1.5159, 2),
#  (95, 1.51629, 2),
#  (96, 1.5186, 2),
#  (97, 1.51841, 2),
#  (98, 1.51743, 2),
#  (99, 1.51689, 2),
#  (100, 1.51811, 2),
#  (101, 1.51655, 2),
#  (102, 1.5173, 2),
#  (103, 1.5182, 2),
#  (104, 1.52725, 2),
#  (105, 1.5241, 2),
#  (106, 1.52475, 2),
#  (107, 1.53125, 2),
#  (108, 1.53393, 2),
#  (109, 1.52222, 2),
#  (110, 1.51818, 2),
#  (111, 1.52664, 2),
#  (112, 1.52739, 2),
#  (113, 1.52777, 2),
#  (114, 1.51892, 2),
#  (115, 1.51847, 2),
#  (116, 1.51846, 2),
# ...

# %%
cursor.execute('select col1, col2, col11 from test.glassdata where col1=11 and col11=2')
cursor.fetchall()
# Out:
# []

# %%
#select all column where col2=1.515 with placeholder
cursor.execute('select *from test.glassdata WHERE col2 LIKE "1.515%"')
cursor.fetchall()
# Out:
# [(6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (36, 1.51567, 13.29, 3.45, 1.21, 72.74, 0.56, 8.57, 0.0, 0.0, 1),
#  (71, 1.51574, 14.86, 3.67, 1.74, 71.87, 0.16, 7.36, 0.0, 0.12, 2),
#  (73, 1.51593, 13.09, 3.59, 1.52, 73.1, 0.67, 7.83, 0.0, 0.0, 2),
#  (75, 1.51596, 13.02, 3.56, 1.54, 73.11, 0.72, 7.9, 0.0, 0.0, 2),
#  (76, 1.5159, 13.02, 3.58, 1.51, 73.12, 0.69, 7.96, 0.0, 0.0, 2),
#  (80, 1.5159, 12.82, 3.52, 1.9, 72.86, 0.69, 7.97, 0.0, 0.0, 2),
#  (81, 1.51592, 12.86, 3.52, 2.12, 72.66, 0.69, 7.97, 0.0, 0.0, 2),
#  (82, 1.51593, 13.25, 3.45, 1.43, 73.17, 0.61, 7.86, 0.0, 0.0, 2),
#  (84, 1.51594, 13.09, 3.52, 1.55, 72.87, 0.68, 8.05, 0.0, 0.09, 2),
#  (87, 1.51569, 13.24, 3.49, 1.47, 73.25, 0.38, 8.03, 0.0, 0.0, 2),
#  (93, 1.51588, 13.12, 3.41, 1.58, 73.26, 0.07, 8.39, 0.0, 0.19, 2),
# ...

# %%
cursor.execute('select * from test.glassdata')
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
#sort with col2 default asc, for desc mention in the syntax
cursor.execute('select * from test.glassdata order by col2 DESC')
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (112, 1.52739, 11.02, 0.0, 0.75, 73.08, 0.0, 14.96, 0.0, 0.0, 2),
#  (104, 1.52725, 13.8, 3.15, 0.66, 70.57, 0.08, 11.64, 0.0, 0.0, 2),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (111, 1.52664, 11.23, 0.0, 0.77, 73.21, 0.0, 14.68, 0.0, 0.0, 2),
#  (132, 1.52614, 13.7, 0.0, 1.36, 71.24, 0.19, 13.44, 0.0, 0.1, 2),
#  (106, 1.52475, 11.45, 0.0, 1.88, 72.19, 0.81, 13.24, 0.0, 0.34, 2),
#  (105, 1.5241, 13.83, 2.9, 1.17, 71.15, 0.08, 10.79, 0.0, 0.0, 2),
#  (171, 1.52369, 13.44, 0.0, 1.58, 72.22, 0.32, 12.24, 0.0, 0.0, 5),
#  (190, 1.52365, 15.79, 1.83, 1.31, 70.43, 0.31, 8.61, 1.68, 0.0, 7),
# ...

# %%
#nested queries
#try to give all column without col1>112, col11=3
cursor.execute('select * from (select *from test.glassdata where col1>112) AS mohan WHERE col11=3')
cursor.fetchall()
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
# ...

# %%
cursor.execute('select *from test.glassdata')
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
# filter out the repeated values of col1
cursor.execute('select * from test.glassdata group by col1')
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute('select * from test.glassdata group by col1 HAVING count(col1)>2')
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %% [raw]
# Task in SQL:
# 1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation
# 2 . create a database called as cardataset
# 3 . create a table called as car with a column name given in dataset description
# 4 . Dump all the data into car table
# 5 . try to check weather all the data is aviable inside your table or not
# 6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value
# 7 . Try to filter a record where col 3 value will be 4 .
# 8.  Try to update a col 3 value with 8 whereever you have value equal to 2
# 9 . try to delete table
# 10 . Try to delete database

# %%
#make sure the car dataset is saved in the current directory

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CE08-50A1
#
#  Directory of C:\Users\mral\Mohana Kalaiyarasan_Data Scientist\FSDS_iNeuron
#
# 07/09/2022  02:56 PM    <DIR>          .
# 07/09/2022  02:56 PM    <DIR>          ..
# 06/09/2022  06:42 PM    <DIR>          .ipynb_checkpoints
# 21/08/2022  04:27 PM    <DIR>          __pycache__
# 10/08/2022  09:56 PM            69,297 1) Python basic_String_list_Indexing.ipynb
# 10/08/2022  10:02 PM            50,566 2) Tuple, Set Dict.ipynb
# 10/08/2022  10:43 PM           226,340 3) 19Dec_Python Prog Discussion.ipynb
# 10/08/2022  10:58 PM            28,649 4) Function_23Dec21.ipynb
# 10/08/2022  11:34 PM            53,772 5) Function_Part2_8Jan22.ipynb
# 10/08/2022  11:55 PM            97,813 6) 9th Jan - Iterator, Generator File System.ipynb
# 14/08/2022  08:32 PM         1,397,957 6.1) Function_Assignment_10Aug2022.ipynb
# 16/08/2022  05:23 PM            28,483 7) Exception Handling.ipynb
# ...

# %%
# create a database called as cardataset
cursor.execute('show databases')
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-10-4296ca1e2eb7> in <module>
#       1 # create a database called as cardataset
# ----> 2 cursor.execute('show databases')
#       3 cursor.fetchall()
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     247         if not self._cnx or self._cnx.is_closed():
#     248             raise ProgrammingError("Cursor is not connected", 2055)
# --> 249         self._cnx.handle_unread_result()
#     250
#     251         stmt = ""
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in handle_unread_result(self, prepared)
#     860             self.consume_results()
#     861         elif unread_result:
# --> 862             raise InternalError("Unread result found")
#     863
# ...

# %%
#database car and Table also car
cursor.execute('USE car')
cursor.execute("show tables from car")
cursor.fetchall()
# Out:
# [('car',)]

# %%
#columns of car
cursor.execute("show columns from car.car")
cursor.fetchall()
# Out:
# [('buying', b'varchar(10)', 'YES', '', None, ''),
#  ('maint', b'varchar(10)', 'YES', '', None, ''),
#  ('doors', b'varchar(10)', 'YES', '', None, ''),
#  ('persons', b'varchar(10)', 'YES', '', None, ''),
#  ('lug_boot', b'varchar(10)', 'YES', '', None, ''),
#  ('safety', b'varchar(10)', 'YES', '', None, ''),
#  ('class_values', b'varchar(10)', 'YES', '', None, '')]

# %%
cursor.execute('create table car(buying VARCHAR(10), maint VARCHAR(10), doors VARCHAR(10),persons VARCHAR(10), lug_boot VARCHAR(10), safety VARCHAR(10),class_values VARCHAR(10))')

# %%
cursor.execute('show tables from car')
cursor.fetchall()
# Out:
# [('car',)]

# %%
cursor.execute('show columns from car.car')
cursor.fetchall()
# Out:
# [('buying', b'varchar(10)', 'YES', '', None, ''),
#  ('maint', b'varchar(10)', 'YES', '', None, ''),
#  ('doors', b'varchar(10)', 'YES', '', None, ''),
#  ('persons', b'varchar(10)', 'YES', '', None, ''),
#  ('lug_boot', b'varchar(10)', 'YES', '', None, ''),
#  ('safety', b'varchar(10)', 'YES', '', None, ''),
#  ('class_values', b'varchar(10)', 'YES', '', None, '')]

# %%
# 4 . Dump all the data into car table
import csv
with open('car.data', 'r') as f:
    car_data = csv.reader(f, delimiter ='\n')
    for i in car_data:
#         print(i)
#         print(type(i[0]))
        s = str(i[0])
        l = len(s.split(','))
        print(i, ':', l)
        if l <7:
            print(f'insert into cardata values ({str(i[0])})')
        else:
            continue
#         cursor.execute('insert into car.car values({values})'.format(values = ((i[0]))))
# Out:
# ['vhigh,vhigh,2,2,small,low,unacc'] : 7
# ['vhigh,vhigh,2,2,small,med,unacc'] : 7
# ['vhigh,vhigh,2,2,small,high,unacc'] : 7
# ['vhigh,vhigh,2,2,med,low,unacc'] : 7
# ['vhigh,vhigh,2,2,med,med,unacc'] : 7
# ['vhigh,vhigh,2,2,med,high,unacc'] : 7
# ['vhigh,vhigh,2,2,big,low,unacc'] : 7
# ['vhigh,vhigh,2,2,big,med,unacc'] : 7
# ['vhigh,vhigh,2,2,big,high,unacc'] : 7
# ['vhigh,vhigh,2,4,small,low,unacc'] : 7
# ['vhigh,vhigh,2,4,small,med,unacc'] : 7
# ['vhigh,vhigh,2,4,small,high,unacc'] : 7
# ['vhigh,vhigh,2,4,med,low,unacc'] : 7
# ['vhigh,vhigh,2,4,med,med,unacc'] : 7
# ['vhigh,vhigh,2,4,med,high,unacc'] : 7
# ['vhigh,vhigh,2,4,big,low,unacc'] : 7
# ['vhigh,vhigh,2,4,big,med,unacc'] : 7
# ['vhigh,vhigh,2,4,big,high,unacc'] : 7
# ['vhigh,vhigh,2,more,small,low,unacc'] : 7
# ['vhigh,vhigh,2,more,small,med,unacc'] : 7
# ['vhigh,vhigh,2,more,small,high,unacc'] : 7
# ['vhigh,vhigh,2,more,med,low,unacc'] : 7
# ['vhigh,vhigh,2,more,med,med,unacc'] : 7
# ...

# %%
with open('car.data', 'r') as f:
    car_data = csv.reader(f, delimiter ='\n')
    for i in car_data:
        lst = i[0].split(',')
        cursor.execute('insert into car.car values("{0}", "{1}", "{2}", "{3}", "{4}", "{5}", "{6}")'.format(lst[0],lst[1],lst[2],lst[3],lst[4],lst[5],lst[6]))

# %%
mydb.commit()

# %%
cursor.execute("select * from car.car")
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
# 5 . try to check weather all the data is aviable inside your table or not 
cursor.execute('select count(*) from car.car')
cursor.fetchall()
# Out:
# [(1728,)]

# %%
# 6 . try to group all the data with COL1 AND count occurences of each and 
# every record based on col1 value 
cursor.execute('select count(*), buying from car.car group by buying')
cursor.fetchall()
# Out:
# [(432, 'vhigh'), (432, 'high'), (432, 'med'), (432, 'low')]

# %%
# 7 . Try to filter a record where col 3 value will be 4 .
cursor.execute('show columns from car.car')
cursor.fetchall()
# Out:
# [('buying', b'varchar(10)', 'YES', '', None, ''),
#  ('maint', b'varchar(10)', 'YES', '', None, ''),
#  ('doors', b'varchar(10)', 'YES', '', None, ''),
#  ('persons', b'varchar(10)', 'YES', '', None, ''),
#  ('lug_boot', b'varchar(10)', 'YES', '', None, ''),
#  ('safety', b'varchar(10)', 'YES', '', None, ''),
#  ('class_values', b'varchar(10)', 'YES', '', None, '')]

# %%
# 7 . Try to filter a record where col 3 value will be 4 .
cursor.execute('select * from car.car WHERE doors = 4')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %%
# 8.  Try to update a col 3 value with 8 whereever you have value equal to 2 
# cursor.execute('select * from car.car where doors =2')
#we need to define the values of varchar as string, within quotes
cursor.execute('UPDATE car.car SET doors = "8" WHERE doors = "2"')
cursor.execute('select *from car.car')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '8', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'med', 'unacc'),
# ...

# %% [raw]
# Another example to write the dump the file
# import csv
# with open(...) as f:
#     car_data = csv.reader(f, delimiter = '\n')
#     print(car_data)
#     query = """insert into cardataset.car(col1, col2, col3, col4, col4, col5, col6, col7) values (%s,%s,%s,%s,%s,%s,%s)"""
#     for i in car_data:
#         split=str(i[0]).split(',')
#
#         cursor.execute(query, split)
#
#     mydb.commit()

# %% [raw]
# To delete the table car and dataset cardataset.
#
# cursor.execute("SET SQL_SAFE_UPDATES = 0")
# cursor.execute("DELETE from cardataset.car")
# cursor.execute("SET SQL_SAFE_UPDATES = 1")
#
# cursor.execute("SET SQL_SAFE_UPDATES = 0")
# cursor.execute("DROP database cardataset")
# cursor.execute("SET SQL_SAFE_UPDATES = 1")
